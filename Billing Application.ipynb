# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox
import math,random,os

class entry:
    def __init__(self,mat):
        self.mat=mat
        self.mat.title('login')
        self.mat.configure(bg='#F5CBA7')
        title=Label(mat,text="WELCOME TO XYZ HOTEL",font=("impact",35,"bold"),fg="orange",bg="white").place(x=90,y=30)
        self.mat.geometry("600x500")
        self.mat.configure(bg="#ffb366")
        
        button1=Button(mat, text="Employee",command=self.login_e)
        button1.place(x=300,y=300)

        button2=Button(mat, text="Admin",command=self.login_a)
        button2.place(x=200,y=300)
    
    def login_a(self):
        self.mat.destroy()
        class login:
            def __init__(self,top):
                self.top=top
                self.top.title('login')
                self.top.geometry('1199x600+100+50')
                self.top.configure(bg='#F5CBA7')

                #-----login frame--
                frame_login=Frame(self.top,bg="white")
                frame_login.place(x=150,y=150,height=340,width=500)
                #---variables--
                self.uname=StringVar()
                self.upass=StringVar()

                title=Label(frame_login,text="Login Here",font=("impact",35,"bold"),fg="orange",bg="white").place(x=90,y=30)

                desc=Label(frame_login,text="Admin Login",font=("echelon",15,"bold"),fg="orange",bg="white").place(x=90,y=100)

                lb_user=Label(frame_login,text="User Name",font=("echelon",15,"bold"),fg="gray",bg="white").place(x=90,y=140)

                self.txt_user=Entry(frame_login,textvariable=self.uname,font=("times new roman",15),bg="lightgray").place(x=90,y=170,width=350,height=35)     # we should give command

                lb_pass=Label(frame_login,text="Password",font=("echelon",15,"bold"),fg="gray",bg="white").place(x=90,y=210)

                self.txt_pass=Entry(frame_login,textvariable=self.upass,font=("times new roman",15),bg="lightgray",show="*").place(x=90,y=240,width=350,height=35)      # command

                log_button=Button(frame_login,text="login",fg="orange",font=("times new roman",12),command=self.login).place(x=140,y=290,width=100)

            def login(self):
                if self.uname.get()=="" or self.upass.get()=="":
                    messagebox.showerror("error","enter id and password")
                elif self.uname.get()=="akhil" and self.upass.get()=="123456":
                    self.top.destroy()
                    class Admin:
                        def __init__ (self,rot):
                            self.rot=rot
                            self.rot.title("ADMIN")
                            self.rot.geometry("1350x700+0+0")
                            self.rot.configure(bg='#F5CBA7')

                            title=Label(self.rot, text="Admin Mode", font=("times new roman",40,"bold"),fg="#17202A",bg='#F5CBA7')
                            title.pack(fill=X)

                            #------------------------Variables--------------------
                            self.ID_var=StringVar()
                            self.Name_var=StringVar()
                            self.Gender_var=StringVar()
                            self.DOB_var=StringVar()
                            self.Contact_var=StringVar()
                            self.Email_var=StringVar()
                            self.Address_var=StringVar()


                    #---------------------------Manage Frame---------------------------------------------#

                            F1=Frame(self.rot, bd=10, relief=RIDGE,bg="#FAD7A0")
                            F1.place(x=20, y=100, width=450, height=600)

                            F1_title=Label(F1, text="Manage Employee", font=("times new roman",25,"bold"),fg="#17202A",bg="#FAD7A0")
                            F1_title.grid(row=0,columnspan=2,pady=20)

                            Emp_ID=Label(F1,text="Emp ID",font=("times new roman",20,"bold"),fg="#17202A",bg="#FAD7A0")
                            Emp_ID.grid(row=1,column=0,pady=10,padx=20,sticky="w")

                            Emp_ID=Entry(F1,textvariable=self.ID_var,font=("times new roman",15,"bold"),bg="#D5DBDB")
                            Emp_ID.grid(row=1,column=1,pady=10,padx=20,sticky="w")

                            Emp_Name=Label(F1,text="Name",font=("times new roman",20,"bold"),fg="#17202A",bg="#FAD7A0")
                            Emp_Name.grid(row=2,column=0,pady=10,padx=20,sticky="w")

                            Emp_Name=Entry(F1,textvariable=self.Name_var,font=("times new roman",15,"bold"),bg="#D5DBDB")
                            Emp_Name.grid(row=2,column=1,pady=10,padx=20,sticky="w")

                            Emp_DOB=Label(F1,text="DOB",font=("times new roman",20,"bold"),fg="#17202A",bg="#FAD7A0")
                            Emp_DOB.grid(row=3,column=0,pady=10,padx=20,sticky="w")

                            Emp_DOB=Entry(F1,textvariable=self.DOB_var,font=("times new roman",15,"bold"),bg="#D5DBDB")
                            Emp_DOB.grid(row=3,column=1,pady=10,padx=20,sticky="w")

                            Emp_Gender=Label(F1,text="Gender",font=("times new roman",20,"bold"),fg="#17202A",bg="#FAD7A0")
                            Emp_Gender.grid(row=4,column=0,pady=10,padx=20,sticky="w")

                            combo_gender=ttk.Combobox(F1,textvariable=self.Gender_var,font=("times new roman",13,"bold"),state="readonly")
                            combo_gender['values']=("Male","Female")
                            combo_gender.grid(row=4,column=1,pady=10,padx=20)


                            Emp_Contact=Label(F1,text="Contact",font=("times new roman",20,"bold"),fg="#17202A",bg="#FAD7A0")
                            Emp_Contact.grid(row=5,column=0,pady=10,padx=20,sticky="w")

                            Emp_Contact=Entry(F1,textvariable=self.Contact_var,font=("times new roman",15,"bold"),bg="#D5DBDB")
                            Emp_Contact.grid(row=5,column=1,pady=10,padx=20,sticky="w")

                            Emp_Email=Label(F1,text="Email ID",font=("times new roman",20,"bold"),fg="#17202A",bg="#FAD7A0")
                            Emp_Email.grid(row=6,column=0,pady=10,padx=20,sticky="w")

                            Emp_Email=Entry(F1,textvariable=self.Email_var,font=("times new roman",15,"bold"),bg="#D5DBDB")
                            Emp_Email.grid(row=6,column=1,pady=10,padx=20,sticky="w")

                            Emp_Address=Label(F1,text="Address",font=("times new roman",20,"bold"),fg="#17202A",bg="#FAD7A0")
                            Emp_Address.grid(row=7,column=0,pady=10,padx=20,sticky="w")

                            self.txt_Address=Text(F1, width=33,height=3,font=("times new roman",10),bg="#D5DBDB")
                            self.txt_Address.grid(row=7,column=1,pady=10,padx=20,sticky="w")

                            #---------------------------Button Frame---------------------------------------------#

                            btn_frame=Frame(F1, bd=4, relief=RIDGE,bg="#FAD7A0")
                            btn_frame.place(x=15, y=500, width=400)

                            Addbtn=Button(btn_frame,text="Add",width=10)
                            Addbtn.grid(row=0,column=0,padx=10,pady=10)

                            Updatebtn=Button(btn_frame,text="Update",width=10)
                            Updatebtn.grid(row=0,column=2,padx=10,pady=10)

                            Deletebtn=Button(btn_frame,text="Delete",width=10)
                            Deletebtn.grid(row=0,column=3,padx=10,pady=10)

                            Clearbtn=Button(btn_frame,text="Clear",width=10)
                            Clearbtn.grid(row=0,column=4,padx=10,pady=10)

                    #---------------------------Detail Frame---------------------------------------------#

                            F2=Frame(self.rot, bd=14, relief=RIDGE,bg="#FAD7A0")
                            F2.place(x=500, y=100, width=800, height=600)

                            search_lbl=Label(F2, text="Search By",bg="#FAD7A0",fg="#17202A",font=("times new roman",20,"bold"))
                            search_lbl.grid(row=0,column=0,pady=10,padx=20,sticky="w")

                            combo_search=ttk.Combobox(F2,width=10,font=("times new roman",13,"bold"),state="readonly")
                            combo_search['values']=("Emp ID","Name","Contact")
                            combo_search.grid(row=0,column=1,pady=10,padx=20)

                            txt_search=Entry(F2, font=("times new roman",13,"bold"),bd=5,relief=GROOVE,bg="#D5DBDB")
                            txt_search.grid(row=0,column=2,pady=10,padx=20,sticky="w")

                            search_btn=Button(F2, text="Search",width=10,pady=5).grid(row=0,column=3,padx=10,pady=10)
                            showall_btn=Button(F2, text="Show All",width=10,pady=5).grid(row=0,column=4,padx=10,pady=10)

                            #---------------------------Table Frame---------------------------------------------#

                            Table_Frame=Frame(F2, bd=4, relief=GROOVE)
                            Table_Frame.place(x=10,y=70,width=760,height=450)

                            scroll_x=Scrollbar(Table_Frame,orient=HORIZONTAL)
                            scroll_y=Scrollbar(Table_Frame,orient=VERTICAL)
                            Employee_table=ttk.Treeview(Table_Frame,columns=("ID","Name","Gender","DOB","Contact","Email","Address"),xscrollcommand=scroll_x.set,yscrollcommand=scroll_y.set)
                            scroll_x.pack(side=BOTTOM,fill=X)
                            scroll_y.pack(side=RIGHT,fill=Y)
                            scroll_x.config(command=Employee_table.xview)
                            scroll_y.config(command=Employee_table.yview)
                            Employee_table.heading("ID",text="ID")
                            Employee_table.heading("Name",text="Name")
                            Employee_table.heading("Gender",text="Gender")
                            Employee_table.heading("DOB",text="DOB")
                            Employee_table.heading("Contact",text="Contact")
                            Employee_table.heading("Email",text="Email")
                            Employee_table.heading("Address",text="Address")
                            Employee_table['show']='headings'
                            Employee_table.column("ID",width=100)
                            Employee_table.column("Name",width=100)
                            Employee_table.column("Gender",width=100)
                            Employee_table.column("DOB",width=100)
                            Employee_table.column("Contact",width=100)
                            Employee_table.column("Email",width=100)
                            Employee_table.column("Address",width=150)

                            Employee_table.pack(fill=BOTH,expand=1)



                    rot=Tk()

                    obj=Admin(rot)
                    rot.mainloop()

                else:
                    messagebox.showerror("error","invalid usename or password")
        
        top=Tk()
        obj=login(top)
        top.mainloop()
        
    
    
    def login_e(self):
        self.mat.destroy()
        class login:
            def __init__(self,top):
                self.top=top
                self.top.title('login')
                self.top.geometry('1199x600+100+50')
                self.top.configure(bg='#F5CBA7')

                #-----login frame--
                frame_login=Frame(self.top,bg="white")
                frame_login.place(x=150,y=150,height=340,width=500)
                #---variables--
                self.uname=StringVar()
                self.upass=StringVar()

                title=Label(frame_login,text="Login Here",font=("impact",35,"bold"),fg="orange",bg="white").place(x=90,y=30)

                desc=Label(frame_login,text="Employee Login",font=("echelon",15,"bold"),fg="orange",bg="white").place(x=90,y=100)

                lb_user=Label(frame_login,text="User Name",font=("echelon",15,"bold"),fg="gray",bg="white").place(x=90,y=140)

                self.txt_user=Entry(frame_login,textvariable=self.uname,font=("times new roman",15),bg="lightgray").place(x=90,y=170,width=350,height=35)     # we should give command

                lb_pass=Label(frame_login,text="Password",font=("echelon",15,"bold"),fg="gray",bg="white").place(x=90,y=210)

                self.txt_pass=Entry(frame_login,textvariable=self.upass,font=("times new roman",15),bg="lightgray",show="*").place(x=90,y=240,width=350,height=35)      # command

                log_button=Button(frame_login,text="login",fg="orange",font=("times new roman",12),command=self.login).place(x=140,y=290,width=100)

            def login(self):
                if self.uname.get()=="" or self.upass.get()=="":
                    messagebox.showerror("error","enter id and password")
                elif self.uname.get()=="akhil" and self.upass.get()=="123456":
                    self.top.destroy()
                    class bill:
                        def __init__(self,root):
                            self.root=root
                            self.root.title('billing page')
                            self.root.geometry('1350x700+0+0')
                            title=Label(self.root,text="Billing System",bd=12,relief=GROOVE,bg="lightblue",fg="white",font=("times new roman",30,"bold"),pady=2).pack(fill=X)
                            #--------variables-----
                            #------cosmatics---
                            self.soap=IntVar()
                            self.face_cream=IntVar()
                            self.face_wash=IntVar()
                            self.spray=IntVar()
                            self.gel=IntVar()
                            self.loshan=IntVar()

                            #----grocerys-----
                            self.rice=IntVar()
                            self.food_oil=IntVar()
                            self.dal=IntVar()
                            self.wheat=IntVar()
                            self.sugar=IntVar()
                            self.tea=IntVar()

                            #-----cold drinks------
                            self.mazza=IntVar()
                            self.cock=IntVar()
                            self.frooty=IntVar()
                            self.thumbsup=IntVar()
                            self.limca=IntVar()
                            self.sprite=IntVar()

                            #-----total cost----
                            self.cosmatic_price=StringVar()
                            self.grocery_price=StringVar()
                            self.cold_drink_price=StringVar()

                            self.cosmatic_tax=StringVar()
                            self.grocery_tax=StringVar()
                            self.cold_drink_tax=StringVar()

                            #--------customar------
                            self.c_name=StringVar()
                            self.c_phone=StringVar()

                            self.bill_no=StringVar()
                            x=random.randint(1000,9999)
                            self.bill_no.set(str(x))
                            self.search_bill=StringVar()





                            #----coustomer details frame
                            f1=LabelFrame(self.root,text="Coustomer Details",bd=12,relief=GROOVE,font=("times new roman",15,"bold"),fg="gold",bg="lightblue")
                            f1.place(x=0,y=80,relwidth=1)

                            cname_lb=Label(f1,text="Customer Name",bg="lightblue",fg="white",font=("times new roman",18,"bold")).grid(row=0,column=0,padx=20,pady=5)
                            cname_txt=Entry(f1,width=15,font="arial 15",bd=7,relief=SUNKEN,bg="lightgray",textvariable=self.c_name).grid(row=0,column=1,pady=5,padx=10)

                            cphn_lb=Label(f1,text="Phone Number",bg="lightblue",fg="white",font=("times new roman",18,"bold")).grid(row=0,column=2,padx=20,pady=5)
                            cphn_txt=Entry(f1,width=15,font="arial 15",bd=7,relief=SUNKEN,bg="lightgray",textvariable=self.c_phone).grid(row=0,column=3,pady=5,padx=10)

                            cbillnbr_lb=Label(f1,text="Bill Number",bg="lightblue",fg="white",font=("times new roman",18,"bold")).grid(row=0,column=4,padx=20,pady=5)
                            cbillnbr_txt=Entry(f1,width=15,font="arial 15",textvariable=self.search_bill,bd=7,relief=SUNKEN,bg="lightgray").grid(row=0,column=5,pady=5,padx=10)

                            cbill_btn=Button(f1,text=("Show Bill"),command=self.find_bill,bd=5,width=10,font=("times new roman",12,"bold")).grid(row=0,column=6,padx=10,pady=10)

                            #------cosmatics table------

                            f2=LabelFrame(self.root,text="Cosmatics",bd=12,relief=GROOVE,font=("times new roman",15,"bold"),fg="gold",bg="lightblue")
                            f2.place(x=5,y=170,width=325,height=380)

                            bath_lb=Label(f2,text="Bath Soap",font=("times new roman",16,"bold"),bg="lightblue").grid(row=0,column=0,padx=10,pady=10,sticky="w")
                            bath_txt=Entry(f2,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.soap).grid(row=0,column=1,padx=10,pady=10)

                            facecream_lb=Label(f2,text="Face Cream",font=("times new roman",16,"bold"),bg="lightblue").grid(row=1,column=0,padx=10,pady=10,sticky="w")
                            facecream_txt=Entry(f2,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.face_cream).grid(row=1,column=1,padx=10,pady=10)

                            facewash_lb=Label(f2,text="Face Wash",font=("times new roman",16,"bold"),bg="lightblue").grid(row=2,column=0,padx=10,pady=10,sticky="w")
                            facewash_txt=Entry(f2,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.face_wash).grid(row=2,column=1,padx=10,pady=10)

                            hairspray_lb=Label(f2,text="Hair Spary",font=("times new roman",16,"bold"),bg="lightblue").grid(row=3,column=0,padx=10,pady=10,sticky="w")
                            hairspray_txt=Entry(f2,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.spray).grid(row=3,column=1,padx=10,pady=10)

                            hairgel_lb=Label(f2,text="Hair Gel",font=("times new roman",16,"bold"),bg="lightblue").grid(row=4,column=0,padx=10,pady=10,sticky="w")
                            hairgel_txt=Entry(f2,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.gel).grid(row=4,column=1,padx=10,pady=10)

                            bodyloshan_lb=Label(f2,text="Body Loshan",font=("times new roman",16,"bold"),bg="lightblue").grid(row=5,column=0,padx=10,pady=10,sticky="w")
                            bodyloshan_txt=Entry(f2,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.loshan).grid(row=5,column=1,padx=10,pady=10)



                            #-------grocery table----

                            f3=LabelFrame(self.root,text="Grocery ",bd=12,relief=GROOVE,font=("times new roman",15,"bold"),fg="gold",bg="lightblue")
                            f3.place(x=330,y=170,width=325,height=380)

                            rice_lb=Label(f3,text="Rice",font=("times new roman",16,"bold"),bg="lightblue").grid(row=0,column=0,padx=10,pady=10,sticky="w")
                            rice_txt=Entry(f3,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.rice).grid(row=0,column=1,padx=10,pady=10)

                            foodoil_lb=Label(f3,text="Food Oil",font=("times new roman",16,"bold"),bg="lightblue").grid(row=1,column=0,padx=10,pady=10,sticky="w")
                            foodoil_txt=Entry(f3,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.food_oil).grid(row=1,column=1,padx=10,pady=10)

                            dal_lb=Label(f3,text="Dal",font=("times new roman",16,"bold"),bg="lightblue").grid(row=2,column=0,padx=10,pady=10,sticky="w")
                            dal_txt=Entry(f3,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.dal).grid(row=2,column=1,padx=10,pady=10)

                            wheat_lb=Label(f3,text="Wheat",font=("times new roman",16,"bold"),bg="lightblue").grid(row=3,column=0,padx=10,pady=10,sticky="w")
                            wheat_txt=Entry(f3,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.wheat).grid(row=3,column=1,padx=10,pady=10)

                            sugar_lb=Label(f3,text="Sugar",font=("times new roman",16,"bold"),bg="lightblue").grid(row=4,column=0,padx=10,pady=10,sticky="w")
                            sugar_txt=Entry(f3,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.sugar).grid(row=4,column=1,padx=10,pady=10)

                            tea_lb=Label(f3,text="Tea",font=("times new roman",16,"bold"),bg="lightblue").grid(row=5,column=0,padx=10,pady=10,sticky="w")
                            tea_txt=Entry(f3,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.tea).grid(row=5,column=1,padx=10,pady=10)


                            #-------cold drinks table----

                            f4=LabelFrame(self.root,text="Cold Drinks",bd=12,relief=GROOVE,font=("times new roman",15,"bold"),fg="gold",bg="lightblue")
                            f4.place(x=655,y=170,width=325,height=380)

                            mazza_lb=Label(f4,text="Mazza",font=("times new roman",16,"bold"),bg="lightblue").grid(row=0,column=0,padx=10,pady=10,sticky="w")
                            mazza_txt=Entry(f4,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.mazza).grid(row=0,column=1,padx=10,pady=10)

                            cock_lb=Label(f4,text="Cock",font=("times new roman",16,"bold"),bg="lightblue").grid(row=1,column=0,padx=10,pady=10,sticky="w")
                            cock_txt=Entry(f4,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.cock).grid(row=1,column=1,padx=10,pady=10)

                            frooty_lb=Label(f4,text="Frooty",font=("times new roman",16,"bold"),bg="lightblue").grid(row=2,column=0,padx=10,pady=10,sticky="w")
                            frooty_txt=Entry(f4,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.frooty).grid(row=2,column=1,padx=10,pady=10)

                            thumbsup_lb=Label(f4,text="Thumbs up",font=("times new roman",16,"bold"),bg="lightblue").grid(row=3,column=0,padx=10,pady=10,sticky="w")
                            thumbsup_txt=Entry(f4,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.thumbsup).grid(row=3,column=1,padx=10,pady=10)

                            limca_lb=Label(f4,text="Limca",font=("times new roman",16,"bold"),bg="lightblue").grid(row=4,column=0,padx=10,pady=10,sticky="w")
                            limca_txt=Entry(f4,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.limca).grid(row=4,column=1,padx=10,pady=10)

                            sprite_lb=Label(f4,text="Sprite",font=("times new roman",16,"bold"),bg="lightblue").grid(row=5,column=0,padx=10,pady=10,sticky="w")
                            sprite_txt=Entry(f4,width=10,font=("times new roman",16,"bold"),bd=5,relief=SUNKEN,textvariable=self.sprite).grid(row=5,column=1,padx=10,pady=10)

                            #-----bill area---
                            f5=Frame(self.root,bd=10,relief=GROOVE)
                            f5.place(x=990,y=170,width=360,height=380)
                            bill_title=Label(f5,text="Bill Area",font="areal 15 bold",bd=7,relief=GROOVE).pack(fill=X)
                            scrol_y=Scrollbar(f5,orient=VERTICAL)
                            self.txtarea=Text(f5,yscrollcommand=scrol_y.set)
                            scrol_y.pack(side=RIGHT,fill=Y)
                            scrol_y.config(command=self.txtarea.yview)
                            self.txtarea.pack(fill=BOTH,expand=1)

                            #-----billing menu----

                            f6=LabelFrame(self.root,text="Billing Menu",bd=12,relief=GROOVE,font=("times new roman",15,"bold"),fg="gold",bg="lightblue")
                            f6.place(x=0,y=560,relwidth=1,height=140)

                            tcosmaticprice_lb=Label(f6,text="Total Cosmatic Price",font=("times new roman",14,"bold"),bg="lightblue").grid(row=0,column=0,padx=20,pady=1,sticky="w")
                            tcosmaticprice_txt=Entry(f6,width=18,font=("times new roman",10,"bold"),bd=7,relief=SUNKEN,textvariable=self.cosmatic_price).grid(row=0,column=1,padx=10,pady=1)

                            tgroceryprice_lb=Label(f6,text="Total Grocery Price",font=("times new roman",14,"bold"),bg="lightblue").grid(row=1,column=0,padx=20,pady=1,sticky="w")
                            tgroceryprice_txt=Entry(f6,width=18,font=("times new roman",10,"bold"),bd=7,relief=SUNKEN,textvariable=self.grocery_price).grid(row=1,column=1,padx=10,pady=1)

                            tcolddrinkprice_lb=Label(f6,text="Total Cold Drink Price",font=("times new roman",14,"bold"),bg="lightblue").grid(row=2,column=0,padx=20,pady=1,sticky="w")
                            tcolddrinkprice_txt=Entry(f6,width=18,font=("times new roman",10,"bold"),bd=7,relief=SUNKEN,textvariable=self.cold_drink_price).grid(row=2,column=1,padx=10,pady=1)

                            cosmatictax_lb=Label(f6,text="Cosmatic Tax",font=("times new roman",14,"bold"),bg="lightblue").grid(row=0,column=3,padx=20,pady=1,sticky="w")
                            cosmatictax_txt=Entry(f6,width=18,font=("times new roman",10,"bold"),bd=7,relief=SUNKEN,textvariable=self.cosmatic_tax).grid(row=0,column=4,padx=5,pady=1)

                            grocerytax_lb=Label(f6,text="Grocery Tax",font=("times new roman",14,"bold"),bg="lightblue").grid(row=1,column=3,padx=20,pady=1,sticky="w")
                            grocerytax_txt=Entry(f6,width=18,font=("times new roman",10,"bold"),bd=7,relief=SUNKEN,textvariable=self.grocery_tax).grid(row=1,column=4,padx=10,pady=1)

                            colddrinktax_lb=Label(f6,text="Cold Drink Tax",font=("times new roman",14,"bold"),bg="lightblue").grid(row=2,column=3,padx=20,pady=1,sticky="w")
                            colddrinktax_txt=Entry(f6,width=18,font=("times new roman",10,"bold"),bd=7,relief=SUNKEN,textvariable=self.cold_drink_tax).grid(row=2,column=4,padx=10,pady=1)

                            buttonframe=Frame(f6,bd=7,relief=GROOVE)
                            buttonframe.place(x=710,width=600,height=100)

                            totalbutton=Button(buttonframe,command=self.total,text="Total",bg="lightblue",fg="white",pady=15,width=10,bd=5,font=("times new roman",15,"bold")).grid(row=0,column=0,padx=5,pady=5)

                            generatebutton=Button(buttonframe,text="Generate Bill",command=self.bill_area,bg="lightblue",fg="white",pady=15,width=10,bd=5,font=("times new roman",15,"bold")).grid(row=0,column=1,padx=5,pady=5)

                            clearbutton=Button(buttonframe,command=self.clear_data,text="Clear",bg="lightblue",fg="white",pady=15,width=10,bd=5,font=("times new roman",15,"bold")).grid(row=0,column=2,padx=5,pady=5)

                            exitbutton=Button(buttonframe,text="Exit",command=self.exit,bg="lightblue",fg="white",pady=15,width=10,bd=5,font=("times new roman",15,"bold")).grid(row=0,column=3,padx=5,pady=5)

                            self.welcome_bill()

                        def total(self):

                            self.c_s_p=self.soap.get()*40
                            self.c_fc_p=self.face_cream.get()*120
                            self.c_fw_p=self.face_wash.get()*60
                            self.c_sp_p=self.spray.get()*180
                            self.c_g_p=self.gel.get()*140
                            self.c_l_p=self.loshan.get()*180


                            self.total_cosmatic_price=float((self.c_s_p)+
                                                       (self.c_fc_p)+
                                                       (self.c_fw_p)+
                                                       (self.c_sp_p)+
                                                       (self.c_g_p)+
                                                       (self.c_l_p)
                                                      )
                            self.cosmatic_price.set("Rs. "+str(self.total_cosmatic_price))
                            self.c_tax=(self.total_cosmatic_price*0.05)
                            self.cosmatic_tax.set("Rs. "+str(self.c_tax))


                            self.c_r_p=self.rice.get()*40
                            self.c_fo_p=self.food_oil.get()*100
                            self.c_d_p=self.dal.get()*60
                            self.c_w_p=self.wheat.get()*60
                            self.c_su_p=self.sugar.get()*60
                            self.c_t_p=self.tea.get()*50


                            self.total_grocery_price=float((self.c_r_p)+
                                                       (self.c_fo_p)+
                                                       (self.c_d_p)+
                                                       (self.c_w_p)+
                                                       (self.c_su_p)+
                                                       (self.c_t_p)
                                                      )
                            self.grocery_price.set("Rs. "+str(self.total_grocery_price))
                            self.g_tax=self.total_grocery_price*0.05
                            self.grocery_tax.set("Rs. "+str(self.g_tax))

                            self.c_m_p=self.mazza.get()*55
                            self.c_c_p=self.cock.get()*55
                            self.c_f_p=self.frooty.get()*50
                            self.c_tu_p=self.thumbsup.get()*60
                            self.c_li_p=self.limca.get()*50
                            self.c_spr_p=self.sprite.get()*60

                            self.total_cold_drink_price=float((self.c_m_p)+
                                                       (self.c_c_p)+
                                                       (self.c_f_p)+
                                                       (self.c_tu_p)+
                                                       (self.c_li_p)+
                                                       (self.c_spr_p)
                                                      )
                            self.cold_drink_price.set("Rs. "+str(self.total_cold_drink_price))
                            self.c_d_tax=self.total_cold_drink_price*0.05
                            self.cold_drink_tax.set("Rs. "+str(self.c_d_tax))

                            self.total_bill=float(self.total_cosmatic_price+
                                                  self.total_grocery_price+
                                                  self.total_cold_drink_price+
                                                  self.c_tax+
                                                  self.g_tax+
                                                  self.c_d_tax
                                                 )

                        #---------------------------bill area---------------                    

                        def welcome_bill(self):

                            self.txtarea.delete('1.0',END)
                            self.txtarea.insert(END,"\t\t Welcome")
                            self.txtarea.insert(END,f"\n=======================================")
                            self.txtarea.insert(END,f"\n Bill Number : {self.bill_no.get()}")  
                            self.txtarea.insert(END,f"\n Customer Name : {self.c_name.get()}")
                            self.txtarea.insert(END,f"\n Phone Number : {self.c_phone.get()}")
                            self.txtarea.insert(END,f"\n=======================================")
                            self.txtarea.insert(END,f"\n Products\t\tQTY\t\tPrice")
                            self.txtarea.insert(END,f"\n=======================================")

                        def bill_area(self):
                            if self.c_name.get()=="" or self.c_phone.get()=="":
                                messagebox.showerror("ERROR","Customer details are must")
                            elif self.cosmatic_price.get()=="Rs. 0.0" and self.grocery_price.get()=="Rs. 0.0" and self.cold_drink_price.get()=="Rs. 0.0":
                                messagebox.showerror("ERROR","No items are selected")
                            else:
                                self.welcome_bill()

                                #------------cosmatics-------

                                if self.soap.get()!=0:
                                    self.txtarea.insert(END,f"\n Bath Soap\t\t{self.soap.get()}\t\t{self.c_s_p}")
                                if self.face_cream.get()!=0:
                                    self.txtarea.insert(END,f"\n Face cream\t\t{self.face_cream.get()}\t\t{self.c_fc_p}")
                                if self.face_wash.get()!=0:
                                    self.txtarea.insert(END,f"\n Face wash\t\t{self.face_wash.get()}\t\t{self.c_fw_p}")
                                if self.spray.get()!=0:
                                    self.txtarea.insert(END,f"\n Spray\t\t{self.spray.get()}\t\t{self.c_sp_p}")
                                if self.gel.get()!=0:
                                    self.txtarea.insert(END,f"\n Hair gel\t\t{self.gel.get()}\t\t{self.c_g_p}")
                                if self.loshan.get()!=0:
                                    self.txtarea.insert(END,f"\n Loshan\t\t{self.loshan.get()}\t\t{self.c_l_p}")

                                #---------------grocery----------------

                                if self.rice.get()!=0:
                                    self.txtarea.insert(END,f"\n Rice\t\t{self.rice.get()}\t\t{self.c_r_p}")
                                if self.food_oil.get()!=0:
                                    self.txtarea.insert(END,f"\n Food oil\t\t{self.food_oil.get()}\t\t{self.c_fo_p}")
                                if self.dal.get()!=0:
                                    self.txtarea.insert(END,f"\n Dal\t\t{self.dal.get()}\t\t{self.c_d_p}")
                                if self.wheat.get()!=0:
                                    self.txtarea.insert(END,f"\n Wheat\t\t{self.wheat.get()}\t\t{self.c_w_p}")
                                if self.sugar.get()!=0:
                                    self.txtarea.insert(END,f"\n Sugar\t\t{self.sugar.get()}\t\t{self.c_su_p}")
                                if self.tea.get()!=0:
                                    self.txtarea.insert(END,f"\n Tea\t\t{self.tea.get()}\t\t{self.c_t_p}")

                                #--------------cold drinks--------------

                                if self.mazza.get()!=0:
                                    self.txtarea.insert(END,f"\n Mazza\t\t{self.mazza.get()}\t\t{self.c_m_p}")
                                if self.cock.get()!=0:
                                    self.txtarea.insert(END,f"\n Cock\t\t{self.cock.get()}\t\t{self.c_c_p}")
                                if self.frooty.get()!=0:
                                    self.txtarea.insert(END,f"\n Frooty\t\t{self.frooty.get()}\t\t{self.c_f_p}")
                                if self.thumbsup.get()!=0:
                                    self.txtarea.insert(END,f"\n Thumbsup\t\t{self.thumbsup.get()}\t\t{self.c_tu_p}")
                                if self.limca.get()!=0:
                                    self.txtarea.insert(END,f"\n Limca\t\t{self.limca.get()}\t\t{self.c_li_p}")
                                if self.sprite.get()!=0:
                                    self.txtarea.insert(END,f"\n Sprite\t\t{self.sprite.get()}\t\t{self.c_spr_p}")

                                self.txtarea.insert(END,f"\n---------------------------------------")
                                self.txtarea.insert(END,f"\n Tax type\t\t\tamount")
                                self.txtarea.insert(END,f"\n---------------------------------------")

                                if self.cosmatic_tax.get()!="Rs. 0.0" :
                                    self.txtarea.insert(END,f"\n Cosmatic Tax\t\t\t{self.cosmatic_tax.get()}")
                                if self.grocery_tax.get()!="Rs. 0.0":
                                    self.txtarea.insert(END,f"\n Grocery Tax\t\t\t{self.grocery_tax.get()}")
                                if self.cold_drink_tax.get()!="Rs. 0.0":
                                    self.txtarea.insert(END,f"\n Cold Drink Tax\t\t\t{self.cold_drink_tax.get()}")

                                self.txtarea.insert(END,f"\n Total Bill : \t\t\tRs. {str(self.total_bill)}")

                                self.txtarea.insert(END,f"\n---------------------------------------")

                                self.save_bill()
                        #----------------------------------------------------------------------------------



                        def save_bill(self):
                            op=messagebox.askyesno("Save Bill","Do you want to save the Bill?")
                            if op>0:
                                self.bill_data=self.txtarea.get('1.0',END)
                                f1=open("coustomerbills/"+str(self.bill_no.get())+".txt","w")   #------create a file in the system with name "coustomerbills"------
                                f1.write(self.bill_data)
                                f1.close()
                                messagebox.showinfo("saved",f"Bill no. :{self.bill_no.get()}  saved successfully")
                            else:
                                return
                        def find_bill(self):
                            present="no"
                            for i in os.listdir("coustomerbills/"):
                                if i.split('.')[0]==self.search_bill.get():
                                    f1=open(f"coustomerbills/{i}","r")
                                    self.txtarea.delete('1.0',END)
                                    for d in f1:
                                        self.txtarea.insert(END,d)
                                    f1.close()
                                    present="yes"
                            if present=="no":
                                messagebox.showerror("error","Invalid bill no.")

                        def clear_data(self):
                            op=messagebox.askyesno("Data","Clear Data")
                            if op>0:
                                #------cosmatics---
                                self.soap.set(0)
                                self.face_cream.set(0)
                                self.face_wash.set(0)
                                self.spray.set(0)
                                self.gel.set(0)
                                self.loshan.set(0)

                                #----grocerys-----
                                self.rice.set(0)
                                self.food_oil.set(0)
                                self.dal.set(0)
                                self.wheat.set(0)
                                self.sugar.set(0)
                                self.tea.set(0)

                                #-----cold drinks------
                                self.mazza.set(0)
                                self.cock.set(0)
                                self.frooty.set(0)
                                self.thumbsup.set(0)
                                self.limca.set(0)
                                self.sprite.set(0)

                                #-----total cost----
                                self.cosmatic_price.set("")
                                self.grocery_price.set("")
                                self.cold_drink_price.set("")

                                self.cosmatic_tax.set("")
                                self.grocery_tax.set("")
                                self.cold_drink_tax.set("")

                                #--------customar------
                                self.c_name.set("")
                                self.c_phone.set("")

                                self.bill_no.set("")
                                x=random.randint(1000,9999)
                                self.bill_no.set(str(x))
                                self.search_bill.set("")
                                self.welcome_bill()
                        def exit(self):
                            op=messagebox.askyesno("Exit","Do you want to Exit?")
                            if op>0:
                                self.root.destroy()




                    root=Tk()
                    obj=bill(root)
                    root.mainloop()            
                else:
                    messagebox.showerror("Error","Invalid usename or password")



        top=Tk()
        obj=login(top)
        top.mainloop()
        
    
mat=Tk()
obj=entry(mat)
mat.mainloop()
